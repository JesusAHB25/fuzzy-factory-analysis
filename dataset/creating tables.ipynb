# %%
import pandas as pd

# %%
df = pd.read_csv('order_items.csv')

df.to_sql()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 df = pd.read_csv('order_items.csv')
# ----> 3 df.to_sql()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_sql() missing 2 required positional arguments: 'name' and 'con'
